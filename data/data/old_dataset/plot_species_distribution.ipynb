# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
data_file = "all_bird_species_image_data.csv"
df = pd.read_csv(data_file, header=0)
df.head()
# Out:
#                 bird_name            bird_name_raw dataset_part  \
# 0       macqueens_bustard       Macqueen's Bustard      part_10
# 1  madaraszs_tiger_parrot  Madarasz's Tiger Parrot      part_10
# 2       madeira_firecrest        Madeira Firecrest      part_10
# 3       magdalena_antbird        Magdalena Antbird      part_10
# 4      magdalena_tapaculo       Magdalena Tapaculo      part_10
#
#                        folder  nb_images
# 0       0. Macqueen's Bustard        237
# 1  0. Madarasz's Tiger Parrot         14
# 2        0. Madeira Firecrest        193
# 3        0. Magdalena Antbird         36
# 4       0. Magdalena Tapaculo         12

# %% [markdown]
# ### Nb species per parts

# %%
images_per_part_df = df.groupby('dataset_part').sum().reset_index() 
sns.barplot(data=images_per_part_df, y='nb_images', x='dataset_part')
plt.xticks(rotation=90)
plt.title("Nb images per dataset part")
# Out:
# Text(0.5, 1.0, 'Nb images per dataset part')

# %% [markdown]
# ### Species per part

# %%
species_per_part_df = df.groupby('dataset_part').count()
species_per_part_df.head()
# Out:
#               bird_name  bird_name_raw  folder  nb_images
# dataset_part
# part_1              198            198     198        199
# part_10             498            498     498        499
# part_11             499            499     499        500
# part_2              197            197     197        198
# part_3              499            499     499        500

# %%
species_per_part_df = df.groupby('dataset_part').count().reset_index()
sns.barplot(data=species_per_part_df, y='bird_name', x='dataset_part')
plt.xticks(rotation=90)
plt.ylabel("nb_species")
plt.title("Nb species per dataset part")
# Out:
# Text(0.5, 1.0, 'Nb species per dataset part')

# %% [markdown]
# ### Images per species

# %%
sns.histplot(data=df, x="nb_images")
# Out:
# <AxesSubplot:xlabel='nb_images', ylabel='Count'>

# %%
sns.kdeplot(data=df, x="nb_images", hue="dataset_part")
# Out:
# <AxesSubplot:xlabel='nb_images', ylabel='Density'>
